# %%
#Q-1
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
#Q-2
odata=pd.read_csv('olympics-Copy1.csv',skiprows=4)
odata
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
#Q-4
odata.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
#Q-5
odata.describe()
# Out:
#             Edition
# count  29216.000000
# mean    1967.713171
# std       32.406293
# min     1896.000000
# 25%     1948.000000
# 50%     1976.000000
# 75%     1996.000000
# max     2008.000000

# %%
#Q-6
odata.shape[1]
# Out:
# 10

# %%
#Q-7
odata.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
#Q-8
odata.index
# Out:
# RangeIndex(start=0, stop=29216, step=1)

# %%
#Q-9
odata.rename(columns={'Edition':'Edition_year','City':'Available_City','Sport':'Sport_name'})
# Out:
#       Available_City  Edition_year Sport_name       Discipline  \
# 0             Athens          1896   Aquatics         Swimming
# 1             Athens          1896   Aquatics         Swimming
# 2             Athens          1896   Aquatics         Swimming
# 3             Athens          1896   Aquatics         Swimming
# 4             Athens          1896   Aquatics         Swimming
# ...              ...           ...        ...              ...
# 29211        Beijing          2008  Wrestling  Wrestling Gre-R
# 29212        Beijing          2008  Wrestling  Wrestling Gre-R
# 29213        Beijing          2008  Wrestling  Wrestling Gre-R
# 29214        Beijing          2008  Wrestling  Wrestling Gre-R
# 29215        Beijing          2008  Wrestling  Wrestling Gre-R
#
#                     Athlete  NOC Gender                       Event  \
# 0             HAJOS, Alfred  HUN    Men              100m freestyle
# 1          HERSCHMANN, Otto  AUT    Men              100m freestyle
# ...

# %%
#Q-10
odata[odata['Medal']=='Gold']
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
odata[odata['Medal']=='Gold']['Athlete'].count()
# Out:
# 9850

# %%
#Q-11
odata[(odata['Event']=='100m')&(odata['Gender']=='Men')&(odata['Medal']=='Gold')]
# Out:
#                         City  Edition      Sport Discipline  \
# 13                    Athens     1896  Athletics  Athletics
# 231                    Paris     1900  Athletics  Athletics
# 737                 St Louis     1904  Athletics  Athletics
# 1191                  London     1908  Athletics  Athletics
# 2022               Stockholm     1912  Athletics  Athletics
# 2996                 Antwerp     1920  Athletics  Athletics
# 4236                   Paris     1924  Athletics  Athletics
# 5095               Amsterdam     1928  Athletics  Athletics
# 5806             Los Angeles     1932  Athletics  Athletics
# 6427                  Berlin     1936  Athletics  Athletics
# 7302                  London     1948  Athletics  Athletics
# 8121                Helsinki     1952  Athletics  Athletics
# 9009   Melbourne / Stockholm     1956  Athletics  Athletics
# 9924                    Rome     1960  Athletics  Athletics
# 10823                  Tokyo     1964  Athletics  Athletics
# ...

# %%
#Q-12
year=odata[odata['Edition']>=1984]
year.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
#Q-13
cou=odata.query(("(Medal=='Gold') and (Event=='singles') and (Sport=='Badminton')"))
cou.sort_values(by='Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 21790    Atlanta     1996  Badminton  Badminton           BANG, Soo-Hyun  KOR
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23720     Sydney     2000  Badminton  Badminton            GONG, Zhichao  CHN
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
# 20049  Barcelona     1992  Badminton  Badminton            SUSANTI, Susi  INA
# 25737     Athens     2004  Badminton  Badminton              ZHANG, Ning  CHN
# 27744    Beijing     2008  Badminton  Badminton              ZHANG, Ning  CHN
#
#       Gender    Event Event_gender Medal
# 21790  Women  singles            W  Gold
# ...

# %%
#Q-14
odata[(odata['Event']=='100m')&(odata['Gender']=='Women')&(odata['Medal']=='Gold')]
# Out:
#                         City  Edition      Sport Discipline  \
# 5098               Amsterdam     1928  Athletics  Athletics
# 5809             Los Angeles     1932  Athletics  Athletics
# 6430                  Berlin     1936  Athletics  Athletics
# 7305                  London     1948  Athletics  Athletics
# 8124                Helsinki     1952  Athletics  Athletics
# 9012   Melbourne / Stockholm     1956  Athletics  Athletics
# 9927                    Rome     1960  Athletics  Athletics
# 10826                  Tokyo     1964  Athletics  Athletics
# 11868                 Mexico     1968  Athletics  Athletics
# 12905                 Munich     1972  Athletics  Athletics
# 14072               Montreal     1976  Athletics  Athletics
# 15377                 Moscow     1980  Athletics  Athletics
# 16797            Los Angeles     1984  Athletics  Athletics
# 18287                  Seoul     1988  Athletics  Athletics
# 19862              Barcelona     1992  Athletics  Athletics
# ...

# %%
#Q-15
odata[(odata['Medal']=='Silver')&(odata['Edition']==2008)].Athlete
# Out:
# 27176            ZHOU, Luxin
# 27179        HEYMANS, Emilie
# 27182    DESPATIE, Alexandre
# 27185       PAKHALINA, Julia
# 27190      HAUSDING, Patrick
#                 ...
# 29200     BEGALIEV, Kanatbek
# 29204       CHANG, Yongxiang
# 29207          FODOR, Zoltan
# 29211         ENGLICH, Mirko
# 29215         BAROEV, Khasan
# Name: Athlete, Length: 663, dtype: object

# %%
#Q-16
odata.groupby(['NOC'])['Edition'].agg(['min','max','count'])
# Out:
#       min   max  count
# NOC
# AFG  2008  2008      1
# AHO  1988  1988      1
# ALG  1984  2008     14
# ANZ  1908  1912     29
# ARG  1924  2008    239
# ..    ...   ...    ...
# VIE  2000  2008      2
# YUG  1924  2000    435
# ZAM  1984  1996      2
# ZIM  1980  2008     23
# ZZX  1896  1904     48
#
# [138 rows x 3 columns]

# %%
odata['Edition'].agg(['min','max','count','mean','median'])
# Out:
# min        1896.000000
# max        2008.000000
# count     29216.000000
# mean       1967.713171
# median     1976.000000
# Name: Edition, dtype: float64
